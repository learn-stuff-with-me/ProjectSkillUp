# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

csv_data_path = Path("d:/Data/csv_data")

file_name = "Popular_Baby_Names.csv"

# %%
df = pd.read_csv(
    csv_data_path / file_name
)

# %%
print(df.sort_values(by=["Rank", "Gender"]))
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  Count  Rank
# 22              2011  FEMALE                    HISPANIC           ISABELLA    331     1
# 322             2011  FEMALE          WHITE NON HISPANIC             ESTHER    224     1
# 1090            2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA    119     1
# 1218            2011  FEMALE          BLACK NON HISPANIC            MADISON    176     1
# 2541            2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA    119     1
# ...              ...     ...                         ...                ...    ...   ...
# 75535           2014    MALE          WHITE NON HISPANIC             Marcel     10   102
# 76139           2014    MALE          WHITE NON HISPANIC              Denis     10   102
# 76142           2014    MALE          WHITE NON HISPANIC              Issac     10   102
# ...

# %%
print(df.dtypes)
# Out:
# Year of Birth          int64
# Gender                object
# Ethnicity             object
# Child's First Name    object
# Count                  int64
# Rank                   int64
# dtype: object

# %%
electric_vehicle_data = pd.read_csv(csv_data_path / "Electric_Vehicle_Population_Data.csv")

# %%
electric_vehicle_data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year', 'Make', 'Model', 'Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID', 'Vehicle Location', 'Electric Utility', '2020 Census Tract'], dtype='object')

# %%
electric_vehicle_data
# Out:
#         VIN (1-10)     County       City State  Postal Code  Model Year     Make    Model                   Electric Vehicle Type  Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  Base MSRP  Legislative District  DOL Vehicle ID             Vehicle Location                               Electric Utility  2020 Census Tract
# 0       WA1E2AFY8R   Thurston    Olympia    WA      98512.0        2024     AUDI     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)              Not eligible due to low battery range            23.0        0.0                  22.0       263239938   POINT (-122.90787 46.9461)                         PUGET SOUND ENERGY INC       5.306701e+10
# ...

# %%
subset = electric_vehicle_data[["Make", "Electric Range"]]

# %%
subset
# Out:
#            Make  Electric Range
# 0          AUDI            23.0
# 1          AUDI            16.0
# 2        NISSAN            84.0
# 3          AUDI           204.0
# 4         TESLA             0.0
# ...         ...             ...
# 264623  HYUNDAI             0.0
# 264624   NISSAN            84.0
# 264625    TESLA             0.0
# 264626    TESLA             0.0
# 264627    TESLA             0.0
#
# [264628 rows x 2 columns]

# %%
grouped_subset = subset.groupby(by=["Make"]).mean()

# %%
grouped_subset.sort_values(by=["Make"])
# Out:
#                         Electric Range
# Make
# ACURA                         0.000000
# ALFA ROMEO                   33.000000
# AUDI                         37.230268
# AZURE DYNAMICS               56.000000
# BENTLEY                      32.375000
# BMW                          28.021779
# BRIGHTDROP                    0.000000
# CADILLAC                      1.729212
# CHEVROLET                    81.211432
# CHRYSLER                     32.166236
# DODGE                        28.525253
# FIAT                         74.782710
# FISKER                        2.260274
# FORD                          7.414303
# GENESIS                       0.000000
# GMC                           0.000000
# HONDA                        14.348673
# HYUNDAI                      12.739599
# JAGUAR                      182.634146
# JEEP                         21.786081
# KIA                          29.877190
# LAMBORGHINI                  25.928571
# LAND ROVER                   48.975124
# ...
